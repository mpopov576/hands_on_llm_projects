# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline

model = AutoModelForCausalLM.from_pretrained(
    "microsoft/Phi-4-mini-instruct",
    device_map="cuda",
    torch_dtype="auto"
)

tokenizer = AutoTokenizer.from_pretrained("microsoft/Phi-4-mini-instruct")

pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    return_full_text=False,
    max_new_tokens=500,
    do_sample=False
)
# Out:
# Loading weights: 100%|██████████| 194/194 [00:11<00:00, 16.59it/s]
# [transformers] Passing `generation_config` together with generation-related arguments=({'max_new_tokens', 'do_sample'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.

# %%
messages = [
    {"role" : "user", "content" : "Create a funny joke about chickens."}
]

prompt = pipe.tokenizer.apply_chat_template(messages, tokenize=False)
print(prompt)
# Out:
# <|user|>Create a funny joke about chickens.<|end|><|endoftext|>

# %%
output = pipe(messages, do_sample=True, temperature=1)
print(output[0]["generated_text"])
# Out:
# [transformers] Both `max_new_tokens` (=500) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Why don't chickens play poker in the jungle? Too many pheasants!

# %%
output = pipe(messages, do_sample=False)
print(output[0]["generated_text"])
# Out:
# [transformers] Both `max_new_tokens` (=500) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Why don't chickens play poker in the jungle? Too many pecking problems!

# %%
persona = "You are an expert in Large Language models. You excel at breaking down complex papers into digestible summaries.\n"
instruction = "Summarize the key findings of the paper provided.\n"
context = "Your summary should extract the most crucial points that can help researchers quickly understand the most vital information of the paper.\n"
data_format = "Create a bullet-point summary that outlines the method. Follow this up with a concise paragraph that encapsulates the main results.\n"
audience = "The summary is designed for busy researchers that quickly need to grasp the newest trends in Large Language Models.\n"
tone = "The tone should be professional and clear.\n"
text = ("LLMS ARE COOL, AND IN THE FUTURE WILL RULE THE WORLD"
        "")
data = f"Text to summarize: {text}"

query = persona + instruction + context + data_format + audience + tone + data

messages = [
    {"role" : "user", "content" : query}
]

output = pipe(messages, do_sample=False)
print(output[0]["generated_text"])
# Out:
# [transformers] You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# [transformers] Both `max_new_tokens` (=500) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# - **Key Findings:**
#   - LLMS (Large Language Models) are becoming increasingly powerful and versatile.
#   - They are expected to dominate various fields, including natural language processing, healthcare, finance, and education.
#   - LLMS can generate human-like text, understand context, and perform complex tasks with high accuracy.
#   - They have the potential to revolutionize industries by automating tasks, providing insights, and enhancing decision-making processes.
#   - Ethical considerations and biases in LLMS are critical areas that need attention to ensure responsible and fair use.
#
# - **Method:**
#   - The paper likely discusses the architecture, training, and applications of LLMS.
#   - It may include experiments demonstrating the models' capabilities in different tasks.
#   - The paper might also address challenges, limitations, and future directions for LLMS research.
#
# - **Main Results:**
#   The paper highlights the transformative potential of Large Language Models, emphasizing their ability to generate human-like text, understand context, and perform complex tasks with high accuracy. LLMS are poised to revolutionize various industries by automating tasks, providing insights, and enhancing decision-making processes. However, the paper also underscores the importance of addressing ethical considerations and biases to ensure responsible and fair use of these powerful models.

# %%
one_shot_prompt = [
{
"role": "user", "content": "A 'Gigamuru' is a type of Japanese musical instrument. An example of a sentence that uses the word Gigamuru is:"
    },
{
"role": "assistant",
"content": "I have a Gigamuru that my uncle gave me as a gift. I love to play it at home."
},
{
"role": "user",
"content": "To 'screeg' something is to swing a sword at it. An example of a sentence that uses the word screeg is:"
}
]
print(tokenizer.apply_chat_template(one_shot_prompt, tokenize=False))

outputs = pipe(one_shot_prompt)
print(outputs[0]["generated_text"])
# Out:
# [transformers] Both `max_new_tokens` (=500) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# <|user|>A 'Gigamuru' is a type of Japanese musical instrument. An example of a sentence that uses the word Gigamuru is:<|end|><|assistant|>I have a Gigamuru that my uncle gave me as a gift. I love to play it at home.<|end|><|user|>To 'screeg' something is to swing a sword at it. An example of a sentence that uses the word screeg is:<|end|><|endoftext|>
# In the medieval fantasy novel, the knight would screeg his enemies with his gleaming sword.

# %%
product_prompt = [
{"role": "user", "content": "Create a name and slogan for a chatbot that leverages LLMs."}
]
outputs = pipe(product_prompt)
product_description = outputs[0]["generated_text"]
print(product_description)
# Out:
# [transformers] Both `max_new_tokens` (=500) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Name: LexiBot
#
# Slogan: "Unlock the Power of Language with LexiBot – Your AI Conversation Partner!"

# %%
sales_prompt = [
{"role": "user", "content": f"Generate a very short sales pitch for the following product: '{product_description}'"}
]
outputs = pipe(sales_prompt)
sales_pitch = outputs[0]["generated_text"]
print(sales_pitch)
# Out:
# [transformers] Both `max_new_tokens` (=500) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Discover the future of communication with LexiBot – your AI conversation partner. Say goodbye to language barriers and hello to seamless, intelligent interactions. LexiBot is here to unlock the power of language for you. Try LexiBot today and experience the revolution in conversation!

# %%
cot_prompt = [
{"role": "user", "content": "Roger has 5 tennis balls. He buys 2 more cans of tennis balls. Each can has 3 tennis balls. How many tennis balls does he have now?"},
{"role": "assistant", "content": "Roger started with 5 balls. 2 cans of 3 tennis balls each is 6 tennis balls. 5 + 6 = 11. The answer is 11."},
{"role": "user", "content": "The cafeteria had 23 apples. If they used 20 to make lunch and bought 6 more, how many apples do they have?"}
]

outputs = pipe(cot_prompt)
print(outputs[0]["generated_text"])
# Out:
# [transformers] Both `max_new_tokens` (=500) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# The cafeteria started with 23 apples. They used 20, so they had 23 - 20 = 3 apples left. Then they bought 6 more, so they now have 3 + 6 = 9 apples. The answer is 9.

# %%
zeroshot_cot_prompt = [
{"role": "user", "content": "The cafeteria had 23 apples. If they used 20 to make lunch and bought 6 more, how many apples do they have? Let's think step-by-step."}
]
# Generate the output
outputs = pipe(zeroshot_cot_prompt)
print(outputs[0]["generated_text"])
# Out:
# [transformers] Both `max_new_tokens` (=500) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Sure, let's break it down step-by-step:
#
# 1. The cafeteria starts with 23 apples.
# 2. They use 20 apples to make lunch.
# 3. After using 20 apples, they have:
#    23 apples - 20 apples = 3 apples left.
# 4. They then buy 6 more apples.
# 5. Adding the 6 new apples to the 3 apples they have left:
#    3 apples + 6 apples = 9 apples.
#
# So, the cafeteria now has 9 apples.

# %%
zeroshot_tot_prompt = [
{"role": "user", "content": "Imagine three different experts are answering this question. All experts will write down 1 step of their thinking, then share it with the group. Then all experts will go on to the next step, etc. If any expert realizes they're wrong at any point then they leave. The question is 'The cafeteria had 23 apples. If they used 20 to make lunch and bought 6 more, how many apples do they have?' Make sure to discuss the results."}
]

output = pipe(zeroshot_tot_prompt)
print(output[0]["generated_text"])
# Out:
# [transformers] Both `max_new_tokens` (=500) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# **Expert 1:**
# Step 1: Start with the initial number of apples, which is 23.
# Step 2: Subtract the apples used for lunch, which is 20. So, 23 - 20 = 3 apples left.
# Step 3: Add the apples bought, which is 6. So, 3 + 6 = 9 apples.
#
# **Expert 2:**
# Step 1: Start with the initial number of apples, which is 23.
# Step 2: Subtract the apples used for lunch, which is 20. So, 23 - 20 = 3 apples left.
# Step 3: Add the apples bought, which is 6. So, 3 + 6 = 9 apples.
#
# **Expert 3:**
# Step 1: Start with the initial number of apples, which is 23.
# Step 2: Subtract the apples used for lunch, which is 20. So, 23 - 20 = 3 apples left.
# Step 3: Add the apples bought, which is 6. So, 3 + 6 = 9 apples.
#
# **Discussion:**
# All three experts followed the same steps and arrived at the same conclusion. The cafeteria now has 9 apples. This result is consistent across all three experts, indicating that the problem was solved correctly.
